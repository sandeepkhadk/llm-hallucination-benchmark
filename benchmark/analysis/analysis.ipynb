# %%
import pandas as pd

# %%
df = pd.read_csv('../../results/table_mechanistic.csv')

# %%
df
# Out:
#            paradigm  n_rows  failure_rate  generator_output_tokens_mean  \
# 0      selfcheckgpt     100          0.00                        235.75
# 1  rag_verification     100          0.00                        235.75
# 2      llm_as_judge     100          0.03                        235.75
#
#    generator_output_tokens_std  metric_n_samples_mean  metric_n_samples_std  \
# 0                    85.770468                    3.0                   0.0
# 1                    85.770468                    NaN                   NaN
# 2                    85.770468                    NaN                   NaN
#
#    selfcheck_sample_tokens_mean_mean  selfcheck_sample_tokens_mean_std  \
# 0                         204.053333                         52.530868
# 1                                NaN                               NaN
# 2                                NaN                               NaN
#
#    detection_overhead_ms_mean  ...  n_retrieved_topk_mean  \
# ...

# %%
df1 = pd.read_csv('../../results_paper/table_mechanistic.csv')

# %%
df1
# Out:
#            paradigm  n_rows  failure_rate  generator_output_tokens_mean  \
# 0      selfcheckgpt     200          0.00                        204.41
# 1  rag_verification     200          0.00                        204.41
# 2      llm_as_judge     200          0.09                        204.41
#
#    generator_output_tokens_std  metric_n_samples_mean  metric_n_samples_std  \
# 0                    99.684033                    5.0                   0.0
# 1                    99.684033                    NaN                   NaN
# 2                    99.684033                    NaN                   NaN
#
#    selfcheck_sample_tokens_mean_mean  selfcheck_sample_tokens_mean_std  \
# 0                            183.642                         52.134386
# 1                                NaN                               NaN
# 2                                NaN                               NaN
#
#    detection_overhead_ms_mean  ...  n_retrieved_topk_mean  \
# ...
